# %% [markdown]
# # Bootcamp DataScience iHub

# %% [markdown]
# ## Gasto de deputados por gênero

# %% [markdown]
# ### Etapas:
#     1. Abrir os datasets do [link]: http://dontpad.com/thaisviana/datascience
#     2. Calcular o gasto por cada deputado em 2018
#     3. Descobrir quem são os deputados em 2018 no nosso dataset
#     4. Filtrar o dataset de informações de deputados pelos deputados na lista do item 3
#     5. Criar um dataset novo com as colunas NOME, GENERO, GASTO
#     6. Calcular qual genero gasta mais em média por número de agentes públicos

# %%
import pandas as pd
from pandas.api.types import is_string_dtype
import numpy as np

# %%
df_2018 = pd.read_csv('data/Ano-2018.csv', sep=';', parse_dates=['datEmissao'])

# %%
df_infos = pd.read_csv('data/deputados.csv', sep=';', parse_dates=['dataNascimento'])

# %% [markdown]
# ## Gasto por cada deputado em 2018

# %%
df_2018 = df_2018[pd.isna(df_2018['sgPartido']) == False]
gasto = df_2018.groupby(['txNomeParlamentar', 'sgPartido'])['vlrDocumento'].sum()

# %%
gasto
# Out:
# txNomeParlamentar     sgPartido
# ABEL MESQUITA JR.     DEM              531047.71
# ADAIL CARNEIRO        PODE             546244.27
# ADALBERTO CAVALCANTI  AVANTE           497902.97
# ADELMO CARNEIRO LEÃO  PT               378203.93
# ADELSON BARRETO       PR               333038.13
#                                          ...
# ZÉ CARLOS             PT               484381.83
# ZÉ GERALDO            PT               505529.11
# ZÉ SILVA              SOLIDARIEDADE    384928.09
# ÁTILA LINS            PP               437089.95
# ÁTILA LIRA            PSB              452594.23
# Name: vlrDocumento, Length: 555, dtype: float64

# %% [markdown]
# ##  Deputados em 2018 no nosso dataset

# %%
lista_de_nomes = df_2018.txNomeParlamentar.unique()

# %%
#gasto.index

# %% [markdown]
# ## Filtrar o dataset de info de deputados pelos deputados na lista

# %%
df_nome_genero = df_infos[df_infos['nome'].isin(lista_de_nomes) == True]
df_nome_genero
# Out:
#                                                     uri  \
# 221   https://dadosabertos.camara.leg.br/api/v2/depu...
# 376   https://dadosabertos.camara.leg.br/api/v2/depu...
# 477   https://dadosabertos.camara.leg.br/api/v2/depu...
# 782   https://dadosabertos.camara.leg.br/api/v2/depu...
# 968   https://dadosabertos.camara.leg.br/api/v2/depu...
# ...                                                 ...
# 7376  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7377  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7597  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7598  https://dadosabertos.camara.leg.br/api/v2/depu...
# 7599  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                             nome  idLegislaturaInicial  idLegislaturaFinal  \
# 221                       MACEDO                     3                   3
# 376                        ROCHA                     5                   9
# 477                       MACEDO                     7                   7
# 782                       MACEDO                    12                  17
# 968                        ROCHA                    16                  16
# ...                          ...                   ...                 ...
# 7376           EURICELIA CARDOSO                    55                  55
# 7377             PROFESSOR PACCO                    55                  55
# 7597               FREITAS DO PT                    55                  55
# 7598  WASHINGTON CORAÇÃO VALENTE                    55                  55
# 7599                FELIPE SOUZA                    55                  55
#
#                            nomeCivil  cpf siglaSexo urlRedeSocial urlWebsite  \
# 221           José Vicente de Macedo  NaN         M           NaN        NaN
# 376         Justiniano José da Rocha  NaN         M           NaN        NaN
# 477         Marcos Antonio de Macedo  NaN         M           NaN        NaN
# 782         Joaquim Manoel de Macedo  NaN         M           NaN        NaN
# 968          Francisco José da Rocha  NaN         M           NaN        NaN
# ...                              ...  ...       ...           ...        ...
# 7376          EURICELIA MELO CARDOSO  NaN         F           NaN        NaN
# 7377     MARCOS PACCO RIBEIRO COELHO  NaN         M           NaN        NaN
# 7597             MILNE FREITAS SOUZA  NaN         M           NaN        NaN
# 7598  WASHINGTON STECANELA CERQUEIRA  NaN         M           NaN        NaN
# 7599      LUIS FELIPE SILVA DE SOUZA  NaN         M           NaN        NaN
#
#      dataNascimento dataFalecimento ufNascimento municipioNascimento
# 221             NaN             NaN          NaN                 NaN
# 376      1812-11-08      1862-07-10           RJ      Rio de Janeiro
# 477      1808-06-18      1872-12-15           PI              Jaicós
# 782      1820-06-24      1882-04-11           RJ            Itaboraí
# 968      1832-02-10             NaN           BA            Salvador
# ...             ...             ...          ...                 ...
# 7376     1976-04-19             NaN           MA              Monção
# 7377     1974-05-12             NaN           DF            Brasília
# 7597     1962-05-06             NaN           MA      Barra do Corda
# 7598     1975-04-01             NaN           DF            Brasília
# 7599     1971-10-04             NaN           AM              Manaus
#
# [569 rows x 13 columns]

# %%
df_nome_genero = df_nome_genero[['nome', 'siglaSexo', 'ufNascimento', 'dataNascimento']]
df_nome_genero.drop_duplicates(subset='nome', keep='first', inplace=True)
df_genero = df_nome_genero
df_genero
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             nome siglaSexo ufNascimento dataNascimento
# 221                       MACEDO         M          NaN            NaN
# 376                        ROCHA         M           RJ     1812-11-08
# 2823                SILVIO COSTA         M           PE     1956-12-23
# 2824                IZALCI LUCAS         M           MG     1956-04-07
# 2825                DANILO FORTE         M           CE     1958-09-01
# ...                          ...       ...          ...            ...
# 7376           EURICELIA CARDOSO         F           MA     1976-04-19
# 7377             PROFESSOR PACCO         M           DF     1974-05-12
# 7597               FREITAS DO PT         M           MA     1962-05-06
# 7598  WASHINGTON CORAÇÃO VALENTE         M           DF     1975-04-01
# 7599                FELIPE SOUZA         M           AM     1971-10-04
#
# [554 rows x 4 columns]

# %% [markdown]
# ## Calcula idade parlamentar

# %%
from datetime import datetime

diferenca_em_dias = datetime.today() - pd.to_datetime(df_nome_genero.dataNascimento)
idade = np.array((diferenca_em_dias.dt.days/365).values, dtype='int')
media = idade[idade > 0].mean()
idade[idade < 0] = int(media)
df_nome_genero['idade'] = idade

df_nome_genero
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                             nome siglaSexo ufNascimento dataNascimento  idade
# 221                       MACEDO         M          NaN            NaN     56
# 376                        ROCHA         M           RJ     1812-11-08    207
# 2823                SILVIO COSTA         M           PE     1956-12-23     63
# 2824                IZALCI LUCAS         M           MG     1956-04-07     63
# 2825                DANILO FORTE         M           CE     1958-09-01     61
# ...                          ...       ...          ...            ...    ...
# 7376           EURICELIA CARDOSO         F           MA     1976-04-19     43
# 7377             PROFESSOR PACCO         M           DF     1974-05-12     45
# 7597               FREITAS DO PT         M           MA     1962-05-06     57
# 7598  WASHINGTON CORAÇÃO VALENTE         M           DF     1975-04-01     44
# 7599                FELIPE SOUZA         M           AM     1971-10-04     48
#
# [554 rows x 5 columns]

# %%
df_nome_genero[df_nome_genero['idade'] > 100].idade = media
df_nome_genero
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                             nome siglaSexo ufNascimento dataNascimento  idade
# 221                       MACEDO         M          NaN            NaN     56
# 376                        ROCHA         M           RJ     1812-11-08    207
# 2823                SILVIO COSTA         M           PE     1956-12-23     63
# 2824                IZALCI LUCAS         M           MG     1956-04-07     63
# 2825                DANILO FORTE         M           CE     1958-09-01     61
# ...                          ...       ...          ...            ...    ...
# 7376           EURICELIA CARDOSO         F           MA     1976-04-19     43
# 7377             PROFESSOR PACCO         M           DF     1974-05-12     45
# 7597               FREITAS DO PT         M           MA     1962-05-06     57
# 7598  WASHINGTON CORAÇÃO VALENTE         M           DF     1975-04-01     44
# 7599                FELIPE SOUZA         M           AM     1971-10-04     48
#
# [554 rows x 5 columns]

# %%
#df_nome_genero = df_nome_genero.sort_values(by='nome', ascending=True)
#df_nome_genero = df_nome_genero.set_index('nome')
df_nome_genero
# Out:
#                             nome siglaSexo ufNascimento dataNascimento  idade
# 221                       MACEDO         M          NaN            NaN     56
# 376                        ROCHA         M           RJ     1812-11-08    207
# 2823                SILVIO COSTA         M           PE     1956-12-23     63
# 2824                IZALCI LUCAS         M           MG     1956-04-07     63
# 2825                DANILO FORTE         M           CE     1958-09-01     61
# ...                          ...       ...          ...            ...    ...
# 7376           EURICELIA CARDOSO         F           MA     1976-04-19     43
# 7377             PROFESSOR PACCO         M           DF     1974-05-12     45
# 7597               FREITAS DO PT         M           MA     1962-05-06     57
# 7598  WASHINGTON CORAÇÃO VALENTE         M           DF     1975-04-01     44
# 7599                FELIPE SOUZA         M           AM     1971-10-04     48
#
# [554 rows x 5 columns]

# %%
#pd.concat([gasto, df_nome_genero], axis=1, sort=False)

# %% [markdown]
# ## AGORA COM MERGE

# %%
gasto_merge = gasto
gasto_merge = gasto_merge.reset_index()
gasto_merge
# Out:
#         txNomeParlamentar      sgPartido  vlrDocumento
# 0       ABEL MESQUITA JR.            DEM     531047.71
# 1          ADAIL CARNEIRO           PODE     546244.27
# 2    ADALBERTO CAVALCANTI         AVANTE     497902.97
# 3    ADELMO CARNEIRO LEÃO             PT     378203.93
# 4         ADELSON BARRETO             PR     333038.13
# ..                    ...            ...           ...
# 550             ZÉ CARLOS             PT     484381.83
# 551            ZÉ GERALDO             PT     505529.11
# 552              ZÉ SILVA  SOLIDARIEDADE     384928.09
# 553            ÁTILA LINS             PP     437089.95
# 554            ÁTILA LIRA            PSB     452594.23
#
# [555 rows x 3 columns]

# %%
gasto_merge = gasto_merge.merge(df_genero, left_on='txNomeParlamentar', right_on='nome')
gasto_merge.columns
gasto_merge
# Out:
#         txNomeParlamentar      sgPartido  vlrDocumento                nome_x  \
# 0       ABEL MESQUITA JR.            DEM     531047.71     ABEL MESQUITA JR.
# 1          ADAIL CARNEIRO           PODE     546244.27        ADAIL CARNEIRO
# 2    ADALBERTO CAVALCANTI         AVANTE     497902.97  ADALBERTO CAVALCANTI
# 3    ADELMO CARNEIRO LEÃO             PT     378203.93  ADELMO CARNEIRO LEÃO
# 4         ADELSON BARRETO             PR     333038.13       ADELSON BARRETO
# ..                    ...            ...           ...                   ...
# 549             ZÉ CARLOS             PT     484381.83             ZÉ CARLOS
# 550            ZÉ GERALDO             PT     505529.11            ZÉ GERALDO
# 551              ZÉ SILVA  SOLIDARIEDADE     384928.09              ZÉ SILVA
# 552            ÁTILA LINS             PP     437089.95            ÁTILA LINS
# 553            ÁTILA LIRA            PSB     452594.23            ÁTILA LIRA
#
#     siglaSexo_x ufNascimento_x dataNascimento_x  idade_x  \
# 0             M             RR       1962-03-29       57
# 1             M             CE       1963-07-11       56
# 2             M             BA       1958-02-10       61
# 3             M             MG       1949-05-25       70
# 4             M             SE       1964-09-22       55
# ..          ...            ...              ...      ...
# 549           M             MA       1955-05-26       64
# 550           M             ES       1961-12-21       58
# 551           M             MG       1963-05-11       56
# 552           M             AM       1950-11-22       69
# 553           M             PI       1947-04-07       72
#
#                    nome_y siglaSexo_y ufNascimento_y dataNascimento_y  \
# 0       ABEL MESQUITA JR.           M             RR       1962-03-29
# 1          ADAIL CARNEIRO           M             CE       1963-07-11
# 2    ADALBERTO CAVALCANTI           M             BA       1958-02-10
# 3    ADELMO CARNEIRO LEÃO           M             MG       1949-05-25
# 4         ADELSON BARRETO           M             SE       1964-09-22
# ..                    ...         ...            ...              ...
# 549             ZÉ CARLOS           M             MA       1955-05-26
# 550            ZÉ GERALDO           M             ES       1961-12-21
# 551              ZÉ SILVA           M             MG       1963-05-11
# 552            ÁTILA LINS           M             AM       1950-11-22
# 553            ÁTILA LIRA           M             PI       1947-04-07
#
#      idade_y                  nome siglaSexo ufNascimento dataNascimento  \
# 0         57     ABEL MESQUITA JR.         M           RR     1962-03-29
# 1         56        ADAIL CARNEIRO         M           CE     1963-07-11
# 2         61  ADALBERTO CAVALCANTI         M           BA     1958-02-10
# 3         70  ADELMO CARNEIRO LEÃO         M           MG     1949-05-25
# 4         55       ADELSON BARRETO         M           SE     1964-09-22
# ..       ...                   ...       ...          ...            ...
# 549       64             ZÉ CARLOS         M           MA     1955-05-26
# 550       58            ZÉ GERALDO         M           ES     1961-12-21
# 551       56              ZÉ SILVA         M           MG     1963-05-11
# 552       69            ÁTILA LINS         M           AM     1950-11-22
# 553       72            ÁTILA LIRA         M           PI     1947-04-07
#
#      idade
# 0       57
# 1       56
# 2       61
# 3       70
# 4       55
# ..     ...
# 549     64
# 550     58
# 551     56
# 552     69
# 553     72
#
# [554 rows x 18 columns]

# %%
X = gasto_merge[['siglaSexo', 'sgPartido', 'idade', 'ufNascimento']]
y = gasto_merge['vlrDocumento']

# %%
X
# Out:
#     siglaSexo      sgPartido  idade ufNascimento
# 0           M            DEM     57           RR
# 1           M           PODE     56           CE
# 2           M         AVANTE     61           BA
# 3           M             PT     70           MG
# 4           M             PR     55           SE
# ..        ...            ...    ...          ...
# 549         M             PT     64           MA
# 550         M             PT     58           ES
# 551         M  SOLIDARIEDADE     56           MG
# 552         M             PP     69           AM
# 553         M            PSB     72           PI
#
# [554 rows x 4 columns]

# %%
y
# Out:
# 0      531047.71
# 1      546244.27
# 2      497902.97
# 3      378203.93
# 4      333038.13
#          ...
# 549    484381.83
# 550    505529.11
# 551    384928.09
# 552    437089.95
# 553    452594.23
# Name: vlrDocumento, Length: 554, dtype: float64

# %%
for n,c in X.items():
    if is_string_dtype(c): X[n] = c.astype('category').cat.as_ordered()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X['siglaSexo'].cat.categories
# Out:
# Index(['F', 'M'], dtype='object')

# %%
X.siglaSexo = X.siglaSexo.cat.rename_categories([0, 1])

# %%
len(X['sgPartido'].cat.categories)
# Out:
# 25

# %%
X.sgPartido = X.sgPartido.cat.rename_categories(range(len(X['sgPartido'].cat.categories)))

# %%
X.ufNascimento = X.ufNascimento.cat.rename_categories(range(len(X['ufNascimento'].cat.categories)))

# %%
X
# Out:
#     siglaSexo sgPartido  idade ufNascimento
# 0           1         1     57           21
# 1           1         7     56            5
# 2           1         0     61            4
# 3           1        20     70           10
# 4           1        11     55           24
# ..        ...       ...    ...          ...
# 549         1        20     64            9
# 550         1        20     58            7
# 551         1        24     56           10
# 552         1         8     69            2
# 553         1        14     72           16
#
# [554 rows x 4 columns]
